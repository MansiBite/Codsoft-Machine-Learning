# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the dataset to a pandas dataframe
credit_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_data.dtypes
# Out:
# Time        int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
# first 5 rows of the dataset
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 249551  154462.0  2.087413 -0.219804 -1.695477 -0.141344  0.658975  0.162965
# 249552  154462.0  1.832239 -0.584370 -0.349910  0.360256 -0.205292  0.936270
# 249553  154462.0  1.848746 -0.189559 -0.655483  1.413752 -0.293697 -0.630004
# 249554  154462.0 -0.441194  1.310385 -0.598552 -0.387949  0.068840 -1.345206
# 249555  154462.0  2.087744 -0.705227 -1.383608 -0.477999 -0.381062 -0.683096
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 249551  0.023231 -0.107625  0.670204  ...  0.148852  0.771253 -0.129306
# 249552 -0.854052  0.393616  1.478552  ...  0.280299  1.166847  0.205371
# 249553 -0.017359 -0.184723  0.648507  ...  0.091671  0.326743  0.110535
# 249554  0.622400  0.202479  0.193563  ...  0.365832  1.205639 -0.059253
# 249555 -0.304686 -0.204620 -0.619702  ... -0.049299  0.382475  0.009296
#
# ...

# %%
#to load some information
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249556 entries, 0 to 249555
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    249556 non-null  float64
#  1   V1      249556 non-null  float64
#  2   V2      249556 non-null  float64
#  3   V3      249556 non-null  float64
#  4   V4      249556 non-null  float64
#  5   V5      249556 non-null  float64
#  6   V6      249556 non-null  float64
#  7   V7      249556 non-null  float64
#  8   V8      249556 non-null  float64
#  9   V9      249556 non-null  float64
#  10  V10     249556 non-null  float64
#  11  V11     249556 non-null  float64
#  12  V12     249556 non-null  float64
#  13  V13     249556 non-null  float64
#  14  V14     249556 non-null  float64
#  15  V15     249556 non-null  float64
#  16  V16     249556 non-null  float64
#  17  V17     249556 non-null  float64
#  18  V18     249556 non-null  float64
#  19  V19     249556 non-null  float64
# ...

# %%
# to check number of missing value in a dataset
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#distribution of legit transaction and fraudlent transaction
credit_data['Class'].value_counts()
# Out:
# 0.0    249100
# 1.0       455
# Name: Class, dtype: int64

# %%
#This dataset is highly unblanced
#0 is normal transaction
#1 is fraudlent transaction
# separating the data for analysis
legit = credit_data[credit_data.Class == 0]
fraud = credit_data[credit_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (249100, 31)
# (455, 31)

# %%
#statistical measure of the data
legit.Amount.describe()
# Out:
# count    249100.000000
# mean         90.671894
# std         251.697188
# min           0.000000
# 25%           6.000000
# 50%          23.060000
# 75%          79.900000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     455.000000
# mean      125.899253
# std       263.669720
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.940000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare the values for both transaction
credit_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    85221.772365 -0.028625 -0.027160  0.116015  0.016414 -0.031710
# 1.0    74238.189011 -5.061266  3.797424 -7.239626  4.602808 -3.461032
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.021502 -0.005882  0.000898  0.005969  ...  0.003925 -0.003207
# 1.0   -1.364870 -5.871040  0.612797 -2.616551  ...  0.360634  0.755254
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.010795 -0.006326  0.000906  0.021514  0.001527 -0.000903  0.000697
# 1.0    0.017598 -0.053131 -0.089009  0.044541  0.042843  0.154087  0.075490
#
#            Amount
# Class
# 0.0     90.671894
# 1.0    125.899253
#
# [2 rows x 30 columns]

# %%
#Build sample dataset conatining similar distribution of normal transaction and fraudlent transaction
#number of normal transaction is 19397
#number of fraudlent transation is 68
legit_sample=legit.sample(n=68)

# %%
#concatenating two dataframe
new_dataframe=pd.concat([legit_sample,fraud],axis=0) #rows

# %%
new_dataframe.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 65996    51838.0 -1.844788  0.096287  1.528294  1.398328  0.711128  0.479595
# 45120    42214.0 -1.132720  1.480929  1.120153 -0.118490 -0.418570 -0.956379
# 153006   97754.0  2.032095 -0.229056 -0.961515  0.518835 -0.283366 -1.008613
# 152189   97048.0 -0.294666  1.457114  0.168589  1.166416  1.161262 -0.840637
# 182836  125569.0  1.740487 -0.563589 -2.385399  1.114643  0.803345 -0.020872
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 65996   1.233938  0.148008 -1.500610  ...  0.201899  0.523106  0.220867
# 45120   0.513268  0.191330  0.062949  ... -0.309647 -0.679097  0.007137
# 153006 -0.104746 -0.335708  2.537663  ... -0.073971  0.312722  0.044106
# 152189  1.287976 -0.452570  0.576835  ... -0.016321  0.544436 -0.315944
# 182836  0.610719 -0.116812  0.317783  ...  0.095060 -0.023297 -0.315998
#
# ...

# %%
new_dataframe.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 247995  153761.0  1.146259  1.403458 -4.159148  2.660107 -0.323217 -1.836071
# 248296  153875.0 -0.613696  3.698772 -5.534941  5.620486  1.649263 -2.335145
# 248971  154181.0 -0.549615  2.219075 -3.522024  0.236995  1.087469 -1.235530
# 249167  154278.0 -1.600211 -3.488130 -6.459303  3.246816 -1.614608 -1.260375
# 249239  154309.0 -0.082983 -3.935919 -2.616709  0.163310 -1.400952 -0.809419
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 247995 -1.623740  0.259562 -1.132044  ...  0.564450  0.445744 -0.141136
# 248296 -0.907188  0.706362 -3.747646  ...  0.319261 -0.471379 -0.075890
# 248971 -0.279313  0.514361 -1.849927  ...  0.364130  0.210428 -0.366019
# 249167  0.288223 -0.048964 -0.734975  ...  1.191175 -0.967141 -1.463421
# 249239  1.501580 -0.471000  1.519743  ...  0.702672 -0.182305 -0.921017
#
# ...

# %%
new_dataframe['Class'].value_counts()
# Out:
# 1.0    455
# 0.0     68
# Name: Class, dtype: int64

# %%
new_dataframe.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    85024.764706 -0.207401 -0.009870  0.316522 -0.255036  0.135973
# 1.0    74238.189011 -5.061266  3.797424 -7.239626  4.602808 -3.461032
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.059585  0.101937 -0.047018  0.389307  ... -0.136441 -0.066426
# 1.0   -1.364870 -5.871040  0.612797 -2.616551  ...  0.360634  0.755254
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.013207 -0.030954  0.029901 -0.053303 -0.093420 -0.013336  0.022295
# 1.0    0.017598 -0.053131 -0.089009  0.044541  0.042843  0.154087  0.075490
#
#            Amount
# Class
# 0.0     68.815294
# 1.0    125.899253
#
# [2 rows x 30 columns]

# %%
#splitting the data into features and targets
x=new_dataframe.drop(columns='Class',axis=1)
y=new_dataframe['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 65996    51838.0 -1.844788  0.096287  1.528294  1.398328  0.711128  0.479595
# 45120    42214.0 -1.132720  1.480929  1.120153 -0.118490 -0.418570 -0.956379
# 153006   97754.0  2.032095 -0.229056 -0.961515  0.518835 -0.283366 -1.008613
# 152189   97048.0 -0.294666  1.457114  0.168589  1.166416  1.161262 -0.840637
# 182836  125569.0  1.740487 -0.563589 -2.385399  1.114643  0.803345 -0.020872
# ...          ...       ...       ...       ...       ...       ...       ...
# 247995  153761.0  1.146259  1.403458 -4.159148  2.660107 -0.323217 -1.836071
# 248296  153875.0 -0.613696  3.698772 -5.534941  5.620486  1.649263 -2.335145
# 248971  154181.0 -0.549615  2.219075 -3.522024  0.236995  1.087469 -1.235530
# 249167  154278.0 -1.600211 -3.488130 -6.459303  3.246816 -1.614608 -1.260375
# 249239  154309.0 -0.082983 -3.935919 -2.616709  0.163310 -1.400952 -0.809419
#
# ...

# %%
print(y)
# Out:
# 65996     0.0
# 45120     0.0
# 153006    0.0
# 152189    0.0
# 182836    0.0
#          ...
# 247995    1.0
# 248296    1.0
# 248971    1.0
# 249167    1.0
# 249239    1.0
# Name: Class, Length: 523, dtype: float64

# %%
#split data into training and testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (523, 30) (418, 30) (105, 30)

# %%
#Model Training
#logistic Regression
model = LogisticRegression()

# %%
#training the logistic Regression Model with Training Data
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#Model Evaluation
#Accuracy Score
#accuracy on training data
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print("Accuracy Score will be on training data :",training_data_accuracy)
# Out:
# Accuracy Score will be : 0.9473684210526315

# %%
#Accuracy on test data
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print("Accuracy score on this testing data :",test_data_accuracy)
# Out:
# Accuracy score on this testing data : 0.9523809523809523
